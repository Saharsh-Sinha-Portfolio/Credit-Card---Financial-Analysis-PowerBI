# %%
import pandas as pd

# Load the dataset
file_path = '/content/Updated Credit Card.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset to understand its structure
data.head()
# Out:
#    Client_Num Card_Category  Annual_Fees  Activation_30_Days  \
# 0   708082083          Blue          200                   0
# 1   708083283          Blue          445                   1
# 2   708084558          Blue          140                   0
# 3   708085458          Blue          250                   1
# 4   708086958          Blue          320                   1
#
#    Customer_Acq_Cost Week_Start_Date Week_Num Qtr  current_year  Credit_Limit  \
# 0                 87      01-01-2023   Week-1  Q1          2023        3544.0
# 1                108      01-01-2023   Week-1  Q1          2023        3421.0
# 2                106      01-01-2023   Week-1  Q1          2023        8258.0
# 3                150      01-01-2023   Week-1  Q1          2023        1438.3
# 4                106      01-01-2023   Week-1  Q1          2023        3128.0
#
#    Total_Revolving_Bal  Total_Trans_Amt  Total_Trans_Vol  \
# 0                 1661            15149              111
# ...

# %% [markdown]
# Outline for Data Analysis
# # Data Overview
#
# Structure and basic information
# # Descriptive statistics
# Data Cleaning
# # New Section
# Missing values
# Data types
# Descriptive Analysis
#
# # Summary statistics
# Distribution of key variables
# Correlation Analysis
#
# # Correlation matrix
# Significant correlations
# Segment Analysis
#
# Analysis by card category
# Analysis by week and quarter
# Analysis by usage type
# Advanced Analysis
#
# # Predictive modeling for customer acquisition cost
# Utilization ratio analysis
# Visualization
#
# # Graphical representations of key findings
# Insights and Recommendations

# %% [markdown]
# # Data Overview

# %%
data.info()

# Display descriptive statistics for numerical columns
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10293 entries, 0 to 10292
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Client_Num             10293 non-null  int64
#  1   Card_Category          10293 non-null  object
#  2   Annual_Fees            10293 non-null  int64
#  3   Activation_30_Days     10293 non-null  int64
#  4   Customer_Acq_Cost      10293 non-null  int64
#  5   Week_Start_Date        10293 non-null  object
#  6   Week_Num               10293 non-null  object
#  7   Qtr                    10293 non-null  object
#  8   current_year           10293 non-null  int64
#  9   Credit_Limit           10293 non-null  float64
#  10  Total_Revolving_Bal    10293 non-null  int64
#  11  Total_Trans_Amt        10293 non-null  int64
#  12  Total_Trans_Vol        10293 non-null  int64
#  13  Avg_Utilization_Ratio  10293 non-null  float64
# ...

# %% [markdown]
# # Initial Observations
#
# **Dataset Structure:**
#
# Total Entries: 10,293
# Columns: 18
#
# Client_Num
#
# *   Card_Category
# *   Annual_Fees
# *   Activation_30_Days
# *   Customer_Acq_Cost
# *   Week_Start_Date
# *   Week_Num
# *   Qtr
# *   current_year
# *   Credit_Limit
# *   Total_Revolving_Bal
# *   Total_Trans_Amt
# *   Total_Trans_Vol
# *   Avg_Utilization_Ratio
# *   Use Chip
# *   Exp Type
# *   Interest_Earned
# *   Delinquent_Acc
#
# # Data Types:
#
# Numeric columns: Client_Num, Annual_Fees,
#
# *   Activation_30_Days, Customer_Acq_Cost, current_year, Credit_Limit, Total_Revolving_Bal, Total_Trans_Amt, Total_Trans_Vol, Avg_Utilization_Ratio, Interest_Earned, Delinquent_Acc.
#
#
#
# *   Categorical columns: Card_Category, Week_Start_Date, Week_Num, Qtr, Use Chip, Exp Type.
#
# # Descriptive Statistics:
#
# *   The Annual_Fees range from 95 to 500.
# *   The Activation_30_Days is a binary variable (0 or 1).
# *   Customer_Acq_Cost varies from 40 to 172.
# *   Credit_Limit has a wide range from 1438.3 to 34516.0.
# *   Total_Revolving_Bal shows that some customers have zero balance.
# *   Total_Trans_Amt and Total_Trans_Vol show significant variation.
# *   Avg_Utilization_Ratio ranges from 0 to nearly 1, indicating various levels of credit usage.
# *   Interest_Earned and Delinquent_Acc also show considerable variation.
#
# # Missing Values:
#
# *   There are no missing values as all columns have the full count of 10,293 entries.

# %% [markdown]
# # Converting Date Columns

# %%
# Convert Week_Start_Date to datetime
data['Week_Start_Date'] = pd.to_datetime(data['Week_Start_Date'], format='%d-%m-%Y') # Specify the correct format

# Verify the conversion
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10293 entries, 0 to 10292
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Client_Num             10293 non-null  int64
#  1   Card_Category          10293 non-null  object
#  2   Annual_Fees            10293 non-null  int64
#  3   Activation_30_Days     10293 non-null  int64
#  4   Customer_Acq_Cost      10293 non-null  int64
#  5   Week_Start_Date        10293 non-null  datetime64[ns]
#  6   Week_Num               10293 non-null  object
#  7   Qtr                    10293 non-null  object
#  8   current_year           10293 non-null  int64
#  9   Credit_Limit           10293 non-null  float64
#  10  Total_Revolving_Bal    10293 non-null  int64
#  11  Total_Trans_Amt        10293 non-null  int64
#  12  Total_Trans_Vol        10293 non-null  int64
#  13  Avg_Utilization_Ratio  10293 non-null  float64
# ...

# %%
# Summary statistics for numerical columns
numerical_summary = data.describe()

# Frequency distribution for categorical columns
categorical_summary = data.describe(include=['object'])

# %%
# Generate summary statistics for numerical columns
numerical_summary = data.describe()

# Generate frequency distribution for categorical columns
categorical_summary = data.describe(include=['object'])

numerical_summary, categorical_summary
# Out:
# (         Client_Num   Annual_Fees  Activation_30_Days  Customer_Acq_Cost  \
#  count  1.029300e+04  10293.000000        10293.000000       10293.000000
#  mean   7.425987e+08    291.606917            0.574565          96.294569
#  min    7.080821e+08     95.000000            0.000000          40.000000
#  25%    7.131155e+08    195.000000            0.000000          79.000000
#  50%    7.180932e+08    295.000000            1.000000          95.000000
#  75%    7.785732e+08    395.000000            1.000000         112.000000
#  max    9.689362e+08    500.000000            1.000000         172.000000
#  std    4.510040e+07    118.498887            0.494433          25.791600
#
#                       Week_Start_Date  current_year  Credit_Limit  \
#  count                          10293       10293.0  10293.000000
#  mean   2023-07-01 07:31:52.795103488        2023.0   8642.414845
#  min              2023-01-01 00:00:00        2023.0   1438.300000
# ...

# %% [markdown]
# # Descriptive Analysis
# Numerical Summary:
#
# *   **Annual_Fees:** Mean of 291.61 with a standard deviation of 118.50. The fees range from 95 to 500.
# *   **Activation_30_Days:** Binary variable with approximately 57.5% of activations occurring within 30 days.
# *   **Customer_Acq_Cost:** Average acquisition cost is 96.29 with a standard deviation of 25.79, ranging from 40 to 172.
# *   **Credit_Limit:** The mean credit limit is 8642.41 with a wide standard deviation of 9097.24, indicating significant variability.
# *   **Total_Revolving_Bal:** The average revolving balance is 1163.97, with values ranging from 0 to 2517.
# *   **Total_Trans_Amt:** Mean transaction amount is 4423.69 with significant variability, ranging from 510 to 79463.
# *   **Total_Trans_Vol:** The number of transactions per client averages 64.82, with a range from 10 to 139.
# *   **Avg_Utilization_Ratio:** The mean utilization ratio is 0.27, indicating that on average, customers use about 27% of their available credit.
# *   **Interest_Earned:** The mean interest earned is 775.53, with a substantial range from 42.14 to 4785.00.
# *   **Delinquent_Acc:** Approximately 6.06% of accounts are delinquent.

# %% [markdown]
# # Categorical Summary:
#
# *   **Card_Category:** The majority of cards
# are categorized as Blue (9384 out of 10293).
# *   **Week_Num:** The dataset includes data for 53 unique weeks, with Week-27 appearing most frequently.
# *   **Qtr:** Data is available for all four quarters, with Q4 being the most frequent.
# *   **Use Chip:** Three usage types are represented: Chip, Swipe, and Online, with Swipe being the most common.
# *   **Exp Type:** There are six unique expense types, with Bills being the most common.

# %% [markdown]
# # Correlation Analysis
# *Let's calculate the correlation matrix for the numerical variables to identify any significant relationships.*

# %%
# Select only numerical columns before calculating the correlation
numerical_data = data.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_data.corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                        Client_Num  Annual_Fees  Activation_30_Days  \
# Client_Num               1.000000    -0.029490            0.013818
# Annual_Fees             -0.029490     1.000000           -0.004815
# Activation_30_Days       0.013818    -0.004815            1.000000
# Customer_Acq_Cost        0.017520     0.007176           -0.005563
# current_year                  NaN          NaN                 NaN
# Credit_Limit             0.008695     0.006404            0.005780
# Total_Revolving_Bal      0.006843     0.001556           -0.009151
# Total_Trans_Amt          0.007968    -0.001242           -0.018316
# Total_Trans_Vol         -0.009272    -0.006008           -0.035931
# Avg_Utilization_Ratio   -0.004887    -0.003813           -0.022809
# Interest_Earned         -0.013820    -0.004915           -0.012793
# Delinquent_Acc          -0.015186    -0.016896            0.010269
#
#                        Customer_Acq_Cost  current_year  Credit_Limit  \
# ...

# %%
# prompt: Using dataframe correlation_matrix: heatmap

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f")
plt.show()

# %%
# Calculate the correlation matrix for the numerical variables
correlation_matrix = data.select_dtypes(include=['number']).corr()

# Segment analysis by Card_Category
card_category_analysis = data.groupby('Card_Category').agg({
    'Annual_Fees': 'mean',
    'Customer_Acq_Cost': 'mean',
    'Credit_Limit': 'mean',
    'Total_Revolving_Bal': 'mean',
    'Total_Trans_Amt': 'mean',
    'Total_Trans_Vol': 'mean',
    'Avg_Utilization_Ratio': 'mean',
    'Interest_Earned': 'mean',
    'Delinquent_Acc': 'mean'
})

# Segment analysis by Use Chip
use_chip_analysis = data.groupby('Use Chip').agg({
    'Annual_Fees': 'mean',
    'Customer_Acq_Cost': 'mean',
    'Credit_Limit': 'mean',
    'Total_Revolving_Bal': 'mean',
    'Total_Trans_Amt': 'mean',
    'Total_Trans_Vol': 'mean',
    'Avg_Utilization_Ratio': 'mean',
    'Interest_Earned': 'mean',
    'Delinquent_Acc': 'mean'
})

# Display the correlation matrix and the segment analyses
correlation_matrix, card_category_analysis, use_chip_analysis
# Out:
# (                       Client_Num  Annual_Fees  Activation_30_Days  \
#  Client_Num               1.000000    -0.029490            0.013818
#  Annual_Fees             -0.029490     1.000000           -0.004815
#  Activation_30_Days       0.013818    -0.004815            1.000000
#  Customer_Acq_Cost        0.017520     0.007176           -0.005563
#  current_year                  NaN          NaN                 NaN
#  Credit_Limit             0.008695     0.006404            0.005780
#  Total_Revolving_Bal      0.006843     0.001556           -0.009151
#  Total_Trans_Amt          0.007968    -0.001242           -0.018316
#  Total_Trans_Vol         -0.009272    -0.006008           -0.035931
#  Avg_Utilization_Ratio   -0.004887    -0.003813           -0.022809
#  Interest_Earned         -0.013820    -0.004915           -0.012793
#  Delinquent_Acc          -0.015186    -0.016896            0.010269
#
#                         Customer_Acq_Cost  current_year  Credit_Limit  \
# ...

# %% [markdown]
# # Correlation Analysis
# **Key Findings:**
#
# *   **Annual_Fees** has a very low correlation
# with other variables, indicating it may not be a strong predictor for other financial metrics.
# *   **Customer_Acq_Cost** shows a small positive correlation with **Total_Trans_Amt **(0.059) and **Total_Trans_Vol** (0.084), suggesting higher transaction volumes might be associated with slightly higher acquisition costs.
# *   ** Credit_Limit** is negatively correlated with **Avg_Utilization_Ratio** (-0.483), meaning higher credit limits tend to result in lower utilization ratios, as expected.
# *   **Total_Revolving_Bal** and **Total_Trans_Amt** show a positive correlation (0.163), indicating that higher transaction amounts often accompany higher revolving balances.
#
#
# # Segment Analysis
# **By Card Category:**
#
# *   **Annual Fees:** Higher for Platinum and Gold cards compared to Blue and Silver.
# *   **Customer Acquisition Cost:** Slightly higher for Gold and Platinum cards.
# *   **Credit Limit:** Highest for Silver cards, followed by Platinum.
# *   **Total Transaction Amount** and Volume Significantly higher for Platinum and Gold cards.
# *   **Avg Utilization Ratio:** Higher for Blue cards, indicating they use a larger percentage of their credit limits.
# *   **Interest Earned:** Highest for Platinum cards.
# Delinquent Accounts: Fairly consistent across categories.
#
# # By Use Chip:
#
# *   **Annual Fees:** Slightly higher for Chip usage.
# *   **Customer Acquisition Cost:** Relatively uniform across usage types.
# *   **Credit Limit:** Highest for Swipe usage.
# *   **Total Transaction Amount** and Volume: Highest for Chip usage.
# *   **Avg Utilization Ratio:** Similar across usage types.
# *     **Interest Earned:** Highest for Chip usage.
# *   **Delinquent Accounts:** Highest for Chip usage, though differences are minimal.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style for the plots
sns.set(style="whitegrid")

# Visualization 1: Distribution of Annual Fees by Card Category
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Card_Category', y='Annual_Fees')
plt.title('Distribution of Annual Fees by Card Category')
plt.xlabel('Card Category')
plt.ylabel('Annual Fees')
plt.show()

# Visualization 2: Average Customer Acquisition Cost by Use Chip
plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Use Chip', y='Customer_Acq_Cost', estimator=lambda x: sum(x) / len(x))
plt.title('Average Customer Acquisition Cost by Use Chip')
plt.xlabel('Use Chip')
plt.ylabel('Customer Acquisition Cost')
plt.show()

# Visualization 3: Correlation Heatmap of Financial Metrics
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Financial Metrics')
plt.show()

# Visualization 4: Average Utilization Ratio by Card Category
plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Card_Category', y='Avg_Utilization_Ratio', estimator=lambda x: sum(x) / len(x))
plt.title('Average Utilization Ratio by Card Category')
plt.xlabel('Card Category')
plt.ylabel('Average Utilization Ratio')
plt.show()

# Visualization 5: Total Transaction Volume by Use Chip
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Use Chip', y='Total_Trans_Vol')
plt.title('Total Transaction Volume by Use Chip')
plt.xlabel('Use Chip')
plt.ylabel('Total Transaction Volume')
plt.show()

# %% [markdown]
# # Visualizations and Key Insights
# 1.  Distribution of Annual Fees by Card
# Category:
#
# *   Observation: Platinum and Gold cards have higher annual fees compared to Blue and Silver cards. There is significant variation within each category.
#
#
# 2.  Average Customer Acquisition Cost by Use Chip:
#
# *   Observation: The acquisition cost is slightly higher for Chip usage compared to Swipe and Online. This might indicate higher initial costs for secure transactions.
#
#
# 3.  Correlation Heatmap of Financial Metrics:
#
# *   Observation: Strong negative correlation between Credit Limit and Avg Utilization Ratio. Mild positive correlations between Customer Acquisition Cost and Total Transaction Amount/Volume.
#
#
# 4.  Average Utilization Ratio by Card Category:
#
# *   Observation: Blue cards have a higher average utilization ratio, indicating higher credit usage. Gold and Platinum cards have lower utilization ratios.
#
#
#
# 5.  Total Transaction Volume by Use Chip:
#
# *   Observation: Chip usage tends to have a higher total transaction volume, suggesting more frequent or higher-value transactions compared to Swipe and Online.

# %% [markdown]
# # Segment Analysis
# *Utilization Ratio by Card Category, Use Chip, and Expense Type:*

# %%
# Descriptive statistics for Avg_Utilization_Ratio
utilization_summary = data['Avg_Utilization_Ratio'].describe()

# Distribution plot of Avg_Utilization_Ratio
plt.figure(figsize=(10, 6))
sns.histplot(data['Avg_Utilization_Ratio'], kde=True)
plt.title('Distribution of Average Utilization Ratio')
plt.xlabel('Average Utilization Ratio')
plt.ylabel('Frequency')
plt.show()

# Segment analysis by Card Category
utilization_by_category = data.groupby('Card_Category')['Avg_Utilization_Ratio'].mean()

# Segment analysis by Use Chip
utilization_by_use_chip = data.groupby('Use Chip')['Avg_Utilization_Ratio'].mean()

# Segment analysis by Expense Type
utilization_by_exp_type = data.groupby('Exp Type')['Avg_Utilization_Ratio'].mean()

utilization_summary, utilization_by_category, utilization_by_use_chip, utilization_by_exp_type
# Out:
# (count    10293.000000
#  mean         0.274535
#  std          0.275214
#  min          0.000000
#  25%          0.023000
#  50%          0.176000
#  75%          0.501000
#  max          0.999000
#  Name: Avg_Utilization_Ratio, dtype: float64,
#  Card_Category
#  Blue        0.291737
#  Gold        0.124793
#  Platinum    0.151224
#  Silver      0.083071
#  Name: Avg_Utilization_Ratio, dtype: float64,
#  Use Chip
#  Chip       0.265318
#  Online     0.273379
#  Swipe      0.277764
#  Name: Avg_Utilization_Ratio, dtype: float64,
#  Exp Type
#  Bills            0.277783
#  Entertainment    0.275652
#  Food             0.292769
#  Fuel             0.283531
#  Grocery          0.259688
#  Travel           0.236251
#  Name: Avg_Utilization_Ratio, dtype: float64)

# %% [markdown]
# # Key Findings from Credit Utilization Analysis
#
# # **Descriptive Analysis:**
#
# *Summary Statistics for Avg_Utilization_Ratio:*
#
# *   **Mean:** 0.2745
# *   **Standard Deviation:** 0.2752
# *   **Median:** 0.1760
# *   **25th Percentile:** 0.0230
# *   **75th Percentile:** 0.5010
# *   **Maximum:** 0.9990

# %% [markdown]
# # **Distribution:**
#
# The distribution of the utilization ratio is right-skewed, indicating that while most customers use a small proportion of their credit limit, a few utilize it extensively.
# Segment Analysis:
# By Card Category:
#
# *   **Blue:** 0.2917
# *   **Gold:** 0.1248
# *   **Platinum**: 0.1512
# *   **Silver:** 0.0831
# *   **Observation:** Blue cardholders have the highest average utilization ratio, indicating they use a larger proportion of their credit limit. Silver cardholders use the least.

# %% [markdown]
# # By Use Chip:
#
# *   **Chip:** 0.2653
# *   **Online:** 0.2734
# *   **Swipe:** 0.2778
# *   **Observation:** Utilization ratios are fairly consistent across usage types, with Swipe showing the highest utilization.

# %% [markdown]
# #By Expense Type:
#
# *   **Bills:** 0.2778
# *   **Entertainment:** 0.2757
# *   **Food:** 0.2928
# *   **Fuel:** 0.2835
# *   **Grocery:** 0.2597
# *   **Travel:** 0.2363
# *   **Observation:** The highest average utilization ratio is seen in Food expenses, while Travel expenses have the lowest utilization.

# %% [markdown]
# #**Predicting Utilization Ratios for the Next Quarter**

# %% [markdown]
# **Objective:** Develop a predictive model to forecast the average utilization ratios for the next quarter based on historical data and key influencing factors.
#
# **Steps for Predictive Modeling**
# 1.   Data Preparation:
#
#
#
# 2.   Feature selection
# Data splitting (train/test)
# Model Selection:
#
# 3.   Choose appropriate algorithms (e.g., Linear Regression, Random Forest, etc.)
# Model Training:
#
# 4.   Train the model on historical data
# Model Evaluation:
#
# 5.   Evaluate model performance using metrics such as RMSE, MAE, R²
# Prediction:
#
# 6.   Predict utilization ratios for the next quarter

# %% [markdown]
# # Step 1: Data Preparation

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Selecting relevant features
features = data[['Annual_Fees', 'Customer_Acq_Cost', 'Credit_Limit', 'Total_Revolving_Bal', 'Total_Trans_Amt', 'Total_Trans_Vol', 'Interest_Earned']]
target = data['Avg_Utilization_Ratio']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Scaling the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Step 2: Model Selection and Training

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Initializing models
linear_model = LinearRegression()
random_forest_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Training the models
linear_model.fit(X_train_scaled, y_train)
random_forest_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# # Step 3: Model Evaluation

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Selecting relevant features
features = data[['Annual_Fees', 'Customer_Acq_Cost', 'Credit_Limit', 'Total_Revolving_Bal', 'Total_Trans_Amt', 'Total_Trans_Vol', 'Interest_Earned']]
target = data['Avg_Utilization_Ratio']

# Splitting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Scaling the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initializing models
linear_model = LinearRegression()
random_forest_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Training the models
linear_model.fit(X_train_scaled, y_train)
random_forest_model.fit(X_train, y_train)

# Making predictions
linear_predictions = linear_model.predict(X_test_scaled)
random_forest_predictions = random_forest_model.predict(X_test)

# Evaluating Linear Regression model
linear_rmse = mean_squared_error(y_test, linear_predictions, squared=False)
linear_mae = mean_absolute_error(y_test, linear_predictions)
linear_r2 = r2_score(y_test, linear_predictions)

# Evaluating Random Forest model
rf_rmse = mean_squared_error(y_test, random_forest_predictions, squared=False)
rf_mae = mean_absolute_error(y_test, random_forest_predictions)
rf_r2 = r2_score(y_test, random_forest_predictions)

linear_rmse, linear_mae, linear_r2, rf_rmse, rf_mae, rf_r2
# Out:
# (0.16146164083859865,
#  0.13580750955119852,
#  0.6455251847641021,
#  0.0045371465359500904,
#  0.0023893734822729444,
#  0.9997200939579319)

# %% [markdown]
# # Model Evaluation Results
# **Linear Regression Model:**
#
# *  RMSE: 0.1615
# *  MAE: 0.1358
# *  R²: 0.6455
#
# **Random Forest Model:**
#
# *  RMSE: 0.0045
# *  MAE: 0.0024
# *  R²: 0.9997
#
# *The Random Forest Model significantly outperforms the Linear Regression Model in predicting the average utilization ratio. It has a much lower RMSE and MAE, and a near-perfect R² score, indicating that it explains almost all the variability in the target variable.*

# %% [markdown]
# # Predict Utilization Ratios for the Next Quarter

# %% [markdown]
# Given the superior performance of the Random Forest Model, we will use it to predict the utilization ratios for the next quarter. We assume that the features for the next quarter would follow a similar distribution.
#
# 1.  Prepare the feature data for the next quarter.
# 2.  Use the trained Random Forest Model to make predictions.

# %% [markdown]
# # Prediction

# %%
# Predicting utilization ratios for the next quarter using the Random Forest model
# For simplicity, we will use the same features distribution for prediction
next_quarter_predictions = random_forest_model.predict(X_test)

# Display predictions
next_quarter_predictions[:10]  # Display first 10 predictions for the next quarter
# Out:
# array([0.06889, 0.15549, 0.02712, 0.06035, 0.07362, 0.     , 0.     ,
#        0.82966, 0.     , 0.     ])

# %% [markdown]
# # Predictions for the Next Quarter
# *Here are the first 10 predicted utilization ratios for the next quarter using the Random Forest model:*
#
# *  0.0689
# *  0.1555
# *  0.0271
# *  0.0604
# *  0.0736
# *  0.0000
# *  0.0000
# *  0.8297
# *  0.0000
# *  0.0000
#
# # Insights
# The predicted utilization ratios show a range of values, with some customers predicted to have very low or zero utilization, while others have higher ratios.
# The model indicates a diverse pattern in credit utilization, reflecting different customer behaviors and financial situations.

# %% [markdown]
# # Identifying High-Risk Customer Profiles
#
# 1.  Define High-Risk Criteria: Determine a threshold for high utilization ratio (e.g., > 0.75).
#
# 2.  Filter High-Risk Customers: Extract customers whose predicted utilization ratios exceed the threshold.
#
# 3.  Analyze High-Risk Profiles: Examine key metrics (Credit Limit, Total_Revolving_Bal, Interest_Earned, Delinquent_Acc) for these high-risk customers.

# %%
# Define the threshold for high utilization ratio
high_risk_threshold = 0.75

# Filter high-risk customers
high_risk_customers = X_test[next_quarter_predictions > high_risk_threshold]
high_risk_customers_predictions = next_quarter_predictions[next_quarter_predictions > high_risk_threshold]

# Convert to DataFrame to add predicted utilization ratio
high_risk_customers_df = pd.DataFrame(high_risk_customers, columns=features.columns)
high_risk_customers_df['Predicted_Utilization_Ratio'] = high_risk_customers_predictions

# Analyze key metrics for high-risk customers
high_risk_analysis = high_risk_customers_df.describe()

high_risk_customers_df.head(), high_risk_analysis
# Out:
# (      Annual_Fees  Customer_Acq_Cost  Credit_Limit  Total_Revolving_Bal  \
#  33            110                131        3031.0                 2517
#  1950          190                112        1440.0                 1211
#  6861          125                 40        2433.0                 1947
#  3316          405                 98        2402.0                 1892
#  518           200                116        1822.0                 1605
#
#        Total_Trans_Amt  Total_Trans_Vol  Interest_Earned  \
#  33               2188               50           350.08
#  1950             2141               40           428.20
#  6861             4269               88           554.97
#  3316             4610               76           599.30
#  518              2538               39           228.42
#
#        Predicted_Utilization_Ratio
#  33                        0.82966
#  1950                      0.84270
#  6861                      0.79816
#  3316                      0.78438
# ...

# %% [markdown]
# # High-Risk Customer Profiles
# **Key Metrics for High-Risk Customers**
#
# *  Total High-Risk Customers: 142
# *  Average Annual Fees: $296.20
#
# *  Average Customer Acquisition Cost: $94.64
#
# *  Average Credit Limit: $2448.80
#
# *  Average Total Revolving Balance: $2042.04
#
# *  Average Total Transaction Amount: $3456.93
#
# *  Average Total Transaction Volume: 60.60
#
# *  Average Interest Earned: $564.55
#
# *  Average Predicted Utilization Ratio: 0.8345

# %% [markdown]
# # Summary Statistics
#
# *  Annual Fees: Range from $95 to $500, with a mean of $296.20.
#
# *  Customer Acquisition Cost: Ranges from $40 to $170, with a mean of $94.64.
#
# *  Credit Limit: Ranges from $1438.30 to $3302.00, with a mean of $2448.80.
#
# *  Total Revolving Balance: Ranges from $1185 to $2517, with a mean of $2042.04.
#
#
# *  Total Transaction Amount: Ranges from $817 to $8804, with a mean of $3456.93.
#
# *  Total Transaction Volume: Ranges from 18 to 111, with a mean of 60.60.
#
# *  Interest Earned: Ranges from $89.39 to $1538.80, with a mean of $564.55.
#
# *  Predicted Utilization Ratio: Ranges from 0.7524 to 0.9752, with a mean of 0.8345.

# %% [markdown]
# # Insights
# **High Utilization:**
#
# *  These customers have high predicted utilization ratios, averaging around 83.45%, indicating they use a significant portion of their available credit.
#
#
# **Credit Limits and Balances: **
#
# *  Despite having relatively low credit limits (mean $2448.80), these customers maintain high revolving balances (mean $2042.04), leading to high utilization.
# Transaction Behavior:
#
# *  These customers have moderate to high transaction amounts (mean $3456.93) and volumes (mean 60.60), suggesting active credit card usage.
#
# **Interest Earned:**
#
# *  Higher interest earned (mean $564.55) suggests that these customers might carry balances and incur interest charges, increasing their risk of delinquency.
